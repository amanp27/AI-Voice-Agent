# %%
from dotenv import load_dotenv
import os

load_dotenv()
# Out:
# python-dotenv could not parse statement starting at line 14
# True

# %%
pip install langchain-openai
# Out:
# Collecting langchain-openai
#   Downloading langchain_openai-1.1.6-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: langchain-core<2.0.0,>=1.2.2 in ./myenv/lib/python3.13/site-packages (from langchain-openai) (1.2.6)
# Requirement already satisfied: openai<3.0.0,>=1.109.1 in ./myenv/lib/python3.13/site-packages (from langchain-openai) (2.14.0)
# Collecting tiktoken<1.0.0,>=0.7.0 (from langchain-openai)
#   Downloading tiktoken-0.12.0-cp313-cp313-manylinux_2_28_x86_64.whl.metadata (6.7 kB)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in ./myenv/lib/python3.13/site-packages (from langchain-core<2.0.0,>=1.2.2->langchain-openai) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in ./myenv/lib/python3.13/site-packages (from langchain-core<2.0.0,>=1.2.2->langchain-openai) (0.6.0)
# Requirement already satisfied: packaging<26.0.0,>=23.2.0 in ./myenv/lib/python3.13/site-packages (from langchain-core<2.0.0,>=1.2.2->langchain-openai) (25.0)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in ./myenv/lib/python3.13/site-packages (from langchain-core<2.0.0,>=1.2.2->langchain-openai) (2.12.5)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in ./myenv/lib/python3.13/site-packages (from langchain-core<2.0.0,>=1.2.2->langchain-openai) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in ./myenv/lib/python3.13/site-packages (from langchain-core<2.0.0,>=1.2.2->langchain-openai) (9.1.2)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in ./myenv/lib/python3.13/site-packages (from langchain-core<2.0.0,>=1.2.2->langchain-openai) (4.15.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in ./myenv/lib/python3.13/site-packages (from langchain-core<2.0.0,>=1.2.2->langchain-openai) (0.12.0)
# Requirement already satisfied: jsonpointer>=1.9 in ./myenv/lib/python3.13/site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.2.2->langchain-openai) (3.0.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in ./myenv/lib/python3.13/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.2->langchain-openai) (0.28.1)
# Requirement already satisfied: orjson>=3.9.14 in ./myenv/lib/python3.13/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.2->langchain-openai) (3.11.5)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in ./myenv/lib/python3.13/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.2->langchain-openai) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in ./myenv/lib/python3.13/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.2->langchain-openai) (2.32.5)
# Requirement already satisfied: zstandard>=0.23.0 in ./myenv/lib/python3.13/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.2->langchain-openai) (0.25.0)
# Requirement already satisfied: anyio in ./myenv/lib/python3.13/site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.2->langchain-openai) (4.12.0)
# Requirement already satisfied: certifi in ./myenv/lib/python3.13/site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.2->langchain-openai) (2026.1.4)
# Requirement already satisfied: httpcore==1.* in ./myenv/lib/python3.13/site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.2->langchain-openai) (1.0.9)
# Requirement already satisfied: idna in ./myenv/lib/python3.13/site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.2->langchain-openai) (3.11)
# Requirement already satisfied: h11>=0.16 in ./myenv/lib/python3.13/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.2->langchain-openai) (0.16.0)
# Requirement already satisfied: distro<2,>=1.7.0 in ./myenv/lib/python3.13/site-packages (from openai<3.0.0,>=1.109.1->langchain-openai) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.10.0 in ./myenv/lib/python3.13/site-packages (from openai<3.0.0,>=1.109.1->langchain-openai) (0.12.0)
# Requirement already satisfied: sniffio in ./myenv/lib/python3.13/site-packages (from openai<3.0.0,>=1.109.1->langchain-openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in ./myenv/lib/python3.13/site-packages (from openai<3.0.0,>=1.109.1->langchain-openai) (4.67.1)
# Requirement already satisfied: annotated-types>=0.6.0 in ./myenv/lib/python3.13/site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.2.2->langchain-openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in ./myenv/lib/python3.13/site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.2.2->langchain-openai) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in ./myenv/lib/python3.13/site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.2.2->langchain-openai) (0.4.2)
# Collecting regex>=2022.1.18 (from tiktoken<1.0.0,>=0.7.0->langchain-openai)
#   Downloading regex-2025.11.3-cp313-cp313-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (40 kB)
# Requirement already satisfied: charset_normalizer<4,>=2 in ./myenv/lib/python3.13/site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.2->langchain-openai) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./myenv/lib/python3.13/site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.2->langchain-openai) (2.6.2)
# Downloading langchain_openai-1.1.6-py3-none-any.whl (84 kB)
# Downloading tiktoken-0.12.0-cp313-cp313-manylinux_2_28_x86_64.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 1.9 MB/s  0:00:00 eta 0:00:01
# Downloading regex-2025.11.3-cp313-cp313-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (803 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 803.5/803.5 kB 2.8 MB/s  0:00:00 eta 0:00:01
# Installing collected packages: regex, tiktoken, langchain-openai
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3/3 [langchain-openai][tiktoken]
# Successfully installed langchain-openai-1.1.6 regex-2025.11.3 tiktoken-0.12.0
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install langchain
# Out:
# Collecting langchain
#   Downloading langchain-1.2.1-py3-none-any.whl.metadata (4.9 kB)
# Requirement already satisfied: langchain-core<2.0.0,>=1.2.1 in ./myenv/lib/python3.13/site-packages (from langchain) (1.2.6)
# Collecting langgraph<1.1.0,>=1.0.2 (from langchain)
#   Using cached langgraph-1.0.5-py3-none-any.whl.metadata (7.4 kB)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in ./myenv/lib/python3.13/site-packages (from langchain) (2.12.5)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in ./myenv/lib/python3.13/site-packages (from langchain-core<2.0.0,>=1.2.1->langchain) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in ./myenv/lib/python3.13/site-packages (from langchain-core<2.0.0,>=1.2.1->langchain) (0.6.0)
# Requirement already satisfied: packaging<26.0.0,>=23.2.0 in ./myenv/lib/python3.13/site-packages (from langchain-core<2.0.0,>=1.2.1->langchain) (25.0)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in ./myenv/lib/python3.13/site-packages (from langchain-core<2.0.0,>=1.2.1->langchain) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in ./myenv/lib/python3.13/site-packages (from langchain-core<2.0.0,>=1.2.1->langchain) (9.1.2)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in ./myenv/lib/python3.13/site-packages (from langchain-core<2.0.0,>=1.2.1->langchain) (4.15.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in ./myenv/lib/python3.13/site-packages (from langchain-core<2.0.0,>=1.2.1->langchain) (0.12.0)
# Requirement already satisfied: jsonpointer>=1.9 in ./myenv/lib/python3.13/site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.2.1->langchain) (3.0.0)
# Collecting langgraph-checkpoint<4.0.0,>=2.1.0 (from langgraph<1.1.0,>=1.0.2->langchain)
#   Using cached langgraph_checkpoint-3.0.1-py3-none-any.whl.metadata (4.7 kB)
# Collecting langgraph-prebuilt<1.1.0,>=1.0.2 (from langgraph<1.1.0,>=1.0.2->langchain)
#   Using cached langgraph_prebuilt-1.0.5-py3-none-any.whl.metadata (5.2 kB)
# Collecting langgraph-sdk<0.4.0,>=0.3.0 (from langgraph<1.1.0,>=1.0.2->langchain)
#   Downloading langgraph_sdk-0.3.1-py3-none-any.whl.metadata (1.6 kB)
# Collecting xxhash>=3.5.0 (from langgraph<1.1.0,>=1.0.2->langchain)
#   Downloading xxhash-3.6.0-cp313-cp313-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (13 kB)
# Collecting ormsgpack>=1.12.0 (from langgraph-checkpoint<4.0.0,>=2.1.0->langgraph<1.1.0,>=1.0.2->langchain)
#   Downloading ormsgpack-1.12.1-cp313-cp313-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.2 kB)
# Requirement already satisfied: httpx>=0.25.2 in ./myenv/lib/python3.13/site-packages (from langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.2->langchain) (0.28.1)
# Requirement already satisfied: orjson>=3.10.1 in ./myenv/lib/python3.13/site-packages (from langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.2->langchain) (3.11.5)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in ./myenv/lib/python3.13/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.1->langchain) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in ./myenv/lib/python3.13/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.1->langchain) (2.32.5)
# Requirement already satisfied: zstandard>=0.23.0 in ./myenv/lib/python3.13/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.1->langchain) (0.25.0)
# Requirement already satisfied: anyio in ./myenv/lib/python3.13/site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.2->langchain) (4.12.0)
# Requirement already satisfied: certifi in ./myenv/lib/python3.13/site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.2->langchain) (2026.1.4)
# Requirement already satisfied: httpcore==1.* in ./myenv/lib/python3.13/site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.2->langchain) (1.0.9)
# Requirement already satisfied: idna in ./myenv/lib/python3.13/site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.2->langchain) (3.11)
# Requirement already satisfied: h11>=0.16 in ./myenv/lib/python3.13/site-packages (from httpcore==1.*->httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.2->langchain) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in ./myenv/lib/python3.13/site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in ./myenv/lib/python3.13/site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in ./myenv/lib/python3.13/site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in ./myenv/lib/python3.13/site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.1->langchain) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./myenv/lib/python3.13/site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.1->langchain) (2.6.2)
# Downloading langchain-1.2.1-py3-none-any.whl (105 kB)
# Using cached langgraph-1.0.5-py3-none-any.whl (157 kB)
# Using cached langgraph_checkpoint-3.0.1-py3-none-any.whl (46 kB)
# Using cached langgraph_prebuilt-1.0.5-py3-none-any.whl (35 kB)
# Downloading langgraph_sdk-0.3.1-py3-none-any.whl (66 kB)
# Downloading ormsgpack-1.12.1-cp313-cp313-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (211 kB)
# Downloading xxhash-3.6.0-cp313-cp313-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (193 kB)
# Installing collected packages: xxhash, ormsgpack, langgraph-sdk, langgraph-checkpoint, langgraph-prebuilt, langgraph, langchain
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7/7 [langchain]/7 [langchain]prebuilt]
# Successfully installed langchain-1.2.1 langgraph-1.0.5 langgraph-checkpoint-3.0.1 langgraph-prebuilt-1.0.5 langgraph-sdk-0.3.1 ormsgpack-1.12.1 xxhash-3.6.0
# Note: you may need to restart the kernel to use updated packages.

# %%
from langchain_openai import ChatOpenAI
from langchain_core.tools import tool
from langchain_core.messages import HumanMessage
import requests

# %%
@tool
def multiplication_tool(a: int, b: int) -> int:
    """Multiplies two numbers together."""
    return a * b

# %%
print(multiplication_tool.invoke({"a": 6, "b": 7}))  # Should output 42
# Out:
# 42
